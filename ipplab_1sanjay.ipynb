# %% [markdown]
# <a href="https://colab.research.google.com/github/saxonmahar/Data_Science/blob/main/ipplab_1sanjay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/sample_data/a.jpg')

plt.subplot(121)
plt.imshow(img, cmap='gray')
plt.title('Original')
plt.xticks([]), plt.yticks([])

plt.subplot(122)
plt.imshow(img, cmap='gray')
plt.title('Grayscale')
plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# write a program to generate a histogram for diffrrent gray images

# %%
img=cv2.imread('/content/sample_data/einstein.jpg')
plt.hist(img.ravel(),256,[0,256])
plt.show()
# Out:
# <ipython-input-18-cc8b1ea543ad>:2: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(),256,[0,256])

# %%
img=cv2.imread('/content/sample_data/a.jpg',0)
plt.hist(img.ravel(),256,[0,256])
plt.show()
# Out:
# <ipython-input-20-e5e358ca8bcb>:2: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(),256,[0,256])

# %%
#write a program to equalize a histogram for an images

# %%
img=cv2.imread('/content/sample_data/einstein.jpg',0)
hist,bins=np.histogram(img.flatten(),256,[0,256])
cdf=hist.cumsum()
cdf_normalized=cdf*hist.max()/cdf.max()
plt.plot(cdf_normalized,color='b')
plt.hist(img.flatten(),256,[0,256],color='r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'),loc='upper left')
plt.show()
# Out:
# <ipython-input-23-b17e492a3efc>:6: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.flatten(),256,[0,256],color='r')
